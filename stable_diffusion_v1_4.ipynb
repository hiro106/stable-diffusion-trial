# %% [markdown]
# <a href="https://colab.research.google.com/github/hiro106/stable-diffusion-trial/blob/main/stable_diffusion_v1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Google Colab で はじめる Stable Diffusion v1.4
# https://note.com/npaka/n/ndd549d2ce556

# %%
# パッケージのインストール
# !pip install diffusers==0.2.4 transformers scipy ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 112 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 30.2 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 163 kB 63.1 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 48.5 MB/s
# ...

# %%
# トークン変数の準備
YOUR_TOKEN="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"

# %%
from diffusers import StableDiffusionPipeline

# StableDiffusionパイプラインの準備
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", use_auth_token=YOUR_TOKEN)
pipe.to("cuda")
# Out:
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/313 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/592 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/71.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/522 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.2.4",
#   "feature_extractor": [
#     "transformers",
#     "CLIPFeatureExtractor"
# ...

# %%
# 画像生成
prompt = "cosmetic bottle reasonable price"
image = pipe(prompt)["sample"][0]
image.save(f"japanese_cat_skipping.png")
# Out:
# 0it [00:00, ?it/s]

# %%
# 画像生成
prompt = "cosmetic bottle authority"
image = pipe(prompt)["sample"][0]
image.save(f"japanese_cat_skipping2.png")
# Out:
# 0it [00:00, ?it/s]

# %%
# 画像生成
prompt = "japanese cat skipping"
image = pipe(prompt)["sample"][0]
image.save(f"japanese_cat_skipping3.png")

# %%
# 画像生成
prompt = "Japanese prime minister in Chiyoda ward"
image = pipe(prompt)["sample"][0]
image.save(f"Japanese_prime_minister_in_Chiyoda_ward.png")

# %%
# 画像生成
prompt = "Japanese prime minister in Chiyoda ward"
image = pipe(prompt)["sample"][0]
image.save(f"Japanese_prime_minister_in_Chiyoda_ward_2.png")

# %%
# 画像生成
prompt = "Japanese prime minister in Chiyoda ward"
image = pipe(prompt)["sample"][0]
image.save(f"Japanese_prime_minister_in_Chiyoda_ward_3.png")

# %%
# 画像生成
prompt = "Photo of a tiger on the top of Mt. Fuji"
image = pipe(prompt)["sample"][0]
image.save(f"Photo of a tiger on the top of Mt. Fuji.png")

# %%
# 画像生成
prompt = "Photo of a tiger on the top of Mt. Fuji"
image = pipe(prompt)["sample"][0]
image.save(f"Photo of a tiger on the top of Mt. Fuji2.png")

# %%
# 画像生成
prompt = "Photo of a tiger on the top of Mt. Fuji"
image = pipe(prompt)["sample"][0]
image.save(f"Photo of a tiger on the top of Mt. Fuji3.png")

# %%
# 画像生成
prompt = "Japanese modern art of Samurai"
image = pipe(prompt)["sample"][0]
image.save(f"Japanese modern art of Samurai.png")

# %%
# 画像生成
prompt = "Japanese modern art of Samurai"
image = pipe(prompt)["sample"][0]
image.save(f"Japanese modern art of Samurai2.png")

# %%
# 画像生成
prompt = "Japanese modern art of Samurai"
image = pipe(prompt)["sample"][0]
image.save(f"Japanese modern art of Samurai3.png")
